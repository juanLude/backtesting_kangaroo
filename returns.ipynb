# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

# %%
df = yf.download("AAPL", start="2020-01-01", end="2022-12-31")
# Out:
# C:\Users\jmlud\AppData\Local\Temp\ipykernel_13760\2552326887.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("AAPL", start="2020-01-01", end="2022-12-31")
# [*********************100%***********************]  1 of 1 completed

# %%
# show dataframe head
df.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.538528  72.598907  71.292319  71.545905  135480400
# 2020-01-03  71.833298  72.594063  71.608692  71.765674  146322800
# 2020-01-06  72.405663  72.444306  70.702997  70.954173  118387200
# 2020-01-07  72.065163  72.671356  71.845385  72.415353  108872000
# 2020-01-08  73.224411  73.526303  71.768086  71.768086  132079200

# %%
volume = df['Volume']
print(volume.head())
# Out:
# Ticker           AAPL
# Date
# 2020-01-02  135480400
# 2020-01-03  146322800
# 2020-01-06  118387200
# 2020-01-07  108872000
# 2020-01-08  132079200

# %%
# Plotting the closing prices
df['Close'].plot(title='AAPL Closing Prices')
plt.show()

# %%
df['Return'] = df['Close'].pct_change()

# %%
# Plot the closing prices
plt.figure(figsize=(12, 6))
plt.plot(df['Return'], label='Daily Return')
plt.ylabel('Returns')
plt.title('AAPL Daily Returns')
plt.grid(True)
plt.show()

# %%
# histogram
plt.hist(df['Close'], bins=50, color='blue', alpha=0.7)
plt.title('AAPL Closing Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# scatter plot
plt.scatter(df.index, df['Close'], alpha=0.5)
plt.title('AAPL Closing Prices Scatter Plot')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.show()
